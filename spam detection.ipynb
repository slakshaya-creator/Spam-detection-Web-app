# %% [markdown]
# <a href="https://colab.research.google.com/github/slakshaya-creator/Spam-detection-Web-app/blob/main/spam%20detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Step 1: Sample data
messages = [
    "Win money now",
    "Free prize available",
    "Hello friend how are you",
    "Let's meet tomorrow",
    "Earn cash quickly",
    "Good morning"
]

labels = [1, 1, 0, 0, 1, 0]  # 1 = Spam, 0 = Not Spam

# Step 2: Convert text to numbers
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(messages)

# Step 3: Train model
model = MultinomialNB()
model.fit(X, labels)

# Step 4: Take user input
msg = input("Enter a message: ")

# Step 5: Predict
msg_vector = vectorizer.transform([msg])
result = model.predict(msg_vector)

# Step 6: Output result
if result[0] == 1:
    print("Spam Message 🚫")
else:
    print("Not Spam ✅")
# Out:
# Enter a message: good morning
# Not Spam ✅
